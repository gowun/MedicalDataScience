# %%
# !pip install shap
# !pip install importlib
# !pip install lifelines
# !pip install plotly

# %%
from google.colab import auth
from google.colab import drive
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', -1)

auth.authenticate_user()
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone https://github.com/gowun/MedicalDataScience.git
# Out:
# fatal: destination path 'MedicalDataScience' already exists and is not an empty directory.

# %%
# %cd ./MedicalDataScience/
# !git pull
# %cd ..
# !ls
# Out:
# /content/MedicalDataScience
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/gowun/MedicalDataScience
#    977db20..4efc3c5  master     -> origin/master
# Updating 977db20..4efc3c5
# Fast-forward
#  BladderCancer_Cho/BladderCancer_Cho.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)
# /content
# adc.json  gdrive  MedicalDataScience  sample_data

# %%
from MedicalDataScience.BladderCancer_Cho.BladderCancer_Cho import BladderCander
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
a = BladderCander()

# %%
a.Xy[0].head()
# Out:
#    1973 WHO grade  Age  CK14 H-score  ...  Squamous  Nested  Others
# 0  3               69   0.000000      ...  0.0       1.0     1.0
# 1  3               72   4.000000      ...  1.0       0.0     0.0
# 2  3               69   20.000000     ...  0.0       0.0     0.0
# 3  3               76   0.000000      ...  0.0       0.0     0.0
# 4  3               77   33.333333     ...  0.0       0.0     0.0
#
# [5 rows x 30 columns]

# %%
a.compare_auces()

# %%
a.do_validation('logistic_regression', a.Xy[0], a.Xy[1])
# Out:
# {'AUC': 0.7321083172147002, 'accuracy': 0.7032967032967034, 'precision': 0.660377358490566, 'recall': 0.7954545454545454, 'f1': 0.7216494845360825, 'mcc': 0.41796896026170766}
# {'AUC': 0.7321083172147002,
#  'accuracy': 0.7032967032967034,
#  'f1': 0.7216494845360825,
#  'mcc': 0.41796896026170766,
#  'precision': 0.660377358490566,
#  'recall': 0.7954545454545454}

# %%
a.do_validation('decision_tree', a.Xy[0], a.Xy[1])
# Out:
# {'AUC': 0.8077852998065763, 'accuracy': 0.7252747252747253, 'precision': 0.6610169491525424, 'recall': 0.8863636363636364, 'f1': 0.7572815533980584, 'mcc': 0.4822993076079789}
# {'AUC': 0.8077852998065763,
#  'accuracy': 0.7252747252747253,
#  'f1': 0.7572815533980584,
#  'mcc': 0.4822993076079789,
#  'precision': 0.6610169491525424,
#  'recall': 0.8863636363636364}

# %%
a.do_validation('decision_tree_only_markers', a.Xy[0], a.Xy[1])
# Out:
# {'AUC': 0.7591876208897486, 'accuracy': 0.7032967032967034, 'precision': 0.639344262295082, 'recall': 0.8863636363636364, 'f1': 0.742857142857143, 'mcc': 0.44464692718408083}
# {'AUC': 0.7591876208897486,
#  'accuracy': 0.7032967032967034,
#  'f1': 0.742857142857143,
#  'mcc': 0.44464692718408083,
#  'precision': 0.639344262295082,
#  'recall': 0.8863636363636364}

# %%
a.do_validation('random_forest', a.Xy[0], a.Xy[1])
# Out:
# {'AUC': 0.8423597678916829, 'accuracy': 0.7252747252747253, 'precision': 0.6727272727272727, 'recall': 0.8409090909090909, 'f1': 0.7474747474747475, 'mcc': 0.4679959736224316}
# {'AUC': 0.8423597678916829,
#  'accuracy': 0.7252747252747253,
#  'f1': 0.7474747474747475,
#  'mcc': 0.4679959736224316,
#  'precision': 0.6727272727272727,
#  'recall': 0.8409090909090909}
